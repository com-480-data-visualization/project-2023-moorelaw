# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

csv = pd.read_csv('../dataset/processor_metadata.csv', encoding= 'utf-8')

sns.set_theme(style="ticks")
# sns.set_theme()

# %%
plot = sns.lineplot(data=csv, x="Years", y="Decode Width", style="Vendor", markers="o", hue="Vendor")
plot.set(ylim=(0, None))
plt.savefig("../public/figure/metadata_figure/decode_width.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/39256555.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   plot = sns.lineplot(data=csv, x="Years", y="Decode Width", style="Vendor", markers="o", hue="Vendor")

# %%
sns.lineplot(data=csv, x="Years", y="ROB",style="Vendor", markers="o", hue="Vendor")
plt.savefig("../public/figure/metadata_figure/rob.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/1985973576.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=csv, x="Years", y="ROB",style="Vendor", markers="o", hue="Vendor")

# %%
plot = sns.lineplot(data=csv, x="Years", y="ALU Count",style="Vendor", markers="o", hue="Vendor")
plot.set(ylim=(0, None))
plt.savefig("../public/figure/metadata_figure/alu_count.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/2507716974.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   plot = sns.lineplot(data=csv, x="Years", y="ALU Count",style="Vendor", markers="o", hue="Vendor")

# %%
sns.lineplot(data=csv, x="Years", y="BTB",style="Vendor", markers="o", hue="Vendor")
plt.savefig("../public/figure/metadata_figure/btb.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/3339396197.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=csv, x="Years", y="BTB",style="Vendor", markers="o", hue="Vendor")

# %%
sns.lineplot(data=csv, x="Years", y="Mop Cache Entry #",style="Vendor", markers="o", hue="Vendor")
plt.savefig("../public/figure/metadata_figure/mop_cache.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/4009925227.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=csv, x="Years", y="Mop Cache Entry #",style="Vendor", markers="o", hue="Vendor")

# %%
plot = sns.lineplot(data=csv, x="Years", y="L1 Instruction Cache Size",style="Vendor", markers="o", hue="Vendor")
plot.set(ylim=(0, None))
plt.savefig("../public/figure/metadata_figure/li1.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/97894287.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   plot = sns.lineplot(data=csv, x="Years", y="L1 Instruction Cache Size",style="Vendor", markers="o", hue="Vendor")

# %%
plot = sns.lineplot(data=csv, x="Years", y="L1 Data Cache Size",style="Vendor", markers="o", hue="Vendor")
plot.set(ylim=(0, None))
plt.savefig("../public/figure/metadata_figure/l1d.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/2842071722.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   plot = sns.lineplot(data=csv, x="Years", y="L1 Data Cache Size",style="Vendor", markers="o", hue="Vendor")

# %%
sns.lineplot(data=csv, x="Years", y="L2 Cache Size",style="Vendor", markers="o", hue="Vendor")
plt.savefig("../public/figure/metadata_figure/l2.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/3263869259.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=csv, x="Years", y="L2 Cache Size",style="Vendor", markers="o", hue="Vendor")

# %%
sns.lineplot(data=csv, x="Years", y="Reservation Station",style="Vendor", markers="o", hue="Vendor")
plt.savefig("../public/figure/metadata_figure/reservation_station.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/2971572766.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=csv, x="Years", y="Reservation Station",style="Vendor", markers="o", hue="Vendor")

# %%
plot = sns.lineplot(data=csv, x="Years", y="AGU Count",style="Vendor", markers="o", hue="Vendor")
plot.set(ylim=(0, None))
plt.savefig("../public/figure/metadata_figure/agu_count.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/3074006273.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   plot = sns.lineplot(data=csv, x="Years", y="AGU Count",style="Vendor", markers="o", hue="Vendor")

# %%
sns.lineplot(data=csv, x="Years", y="Load Queue Entry #",style="Vendor", markers="o", hue="Vendor")
plt.savefig("../public/figure/metadata_figure/load_queue.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/4000682343.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=csv, x="Years", y="Load Queue Entry #",style="Vendor", markers="o", hue="Vendor")

# %%
sns.lineplot(data=csv, x="Years", y="Store Queue Entry #", style="Vendor", markers="o", hue="Vendor")
plt.savefig("../public/figure/metadata_figure/store_queue.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/714631807.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=csv, x="Years", y="Store Queue Entry #", style="Vendor", markers="o", hue="Vendor")

# %%
sns.lineplot(data=csv, x="Years", y="Fill Buffer Entry #",style="Vendor", markers="o", hue="Vendor")
plt.savefig("../public/figure/metadata_figure/fill_buffer.svg", format="svg")
# Out:
# /tmp/ipykernel_1114891/3059923487.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=csv, x="Years", y="Fill Buffer Entry #",style="Vendor", markers="o", hue="Vendor")
